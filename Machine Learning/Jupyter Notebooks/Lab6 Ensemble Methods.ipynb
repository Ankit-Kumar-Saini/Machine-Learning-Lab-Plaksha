# %% [markdown]
# # Ensemble Methods

# %% [markdown]
# ### Import necessary modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, VotingClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV

# %% [markdown]
# ### Read the data into pandas dataframe

# %%
## Column names for the data set

columns = ['radius', 'texture', 'perimeter', 'area', 'smoothness', 'compactness', 'concavity', 'concave_points', 'symmetry', 
          'fractal_dimension']

cols = ['ID', 'Diagnosis']

for column in columns:
    cols.append(column +'_mean')

for column in columns:
    cols.append(column +'_se')   
    
for column in columns:
    cols.append(column +'_worst')
    
cols
# Out:
# ['ID',
#  'Diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave_points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave_points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave_points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
# read the dataset into pandas dataframe
df = pd.read_csv('wdbc.data', names = cols)
df.head()
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# check the shape of the dataframe
df.shape
# Out:
# (569, 32)

# %%
## basic info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       569 non-null    int64
#  1   Diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave_points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave_points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
## basic description about the dataset
df.describe().T
# Out:
#                          count          mean           std          min  \
# ID                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave_points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave_points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave_points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
#
#                                    25%            50%           75%  \
# ID                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave_points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave_points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave_points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
#
#                                   max
# ID                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave_points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave_points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave_points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01

# %%
## Number of examples of each class
df.Diagnosis.value_counts().plot(kind = 'bar', title = 'Number of examples in each class', figsize = (10, 6),
                                 xlabel = 'Cancer_Type', ylabel = 'Counts');

# %% [markdown]
# ### Let's plot the distribution of each column in the dataset

# %%
def plot_histogram(column_name):
    """ This function will plot the histogram of related columns in the dataset, i.e.(radius_mean, radius_se, radius_worst)
    
    Args: 
        column_name: dataframe column for plotting histogram
    """
    fig, ax = plt.subplots(1, 3, figsize = (14, 6))
    columns = [column_name + '_mean', column_name + '_se', column_name + '_worst']
    for i in range(3):
        sns.kdeplot(df[columns[i]], ax = ax[i], shade = True, color = 'r')
        
    fig.suptitle(f'Histogram of {column_name} columns', fontsize = 18)

# %%
## Call the function to plot histograms
for col in columns:
    plot_histogram(col)

# %% [markdown]
# ### Plot the correlation matrix to see the extent of correlations among the features quantitatively

# %%
random_state = np.random.RandomState(0)
corr = df.iloc[:, 2:].corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
# #T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col0,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row1_col1,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row2_col0,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row2_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col3,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col4,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row5_col5,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row6_col6,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row7_col7,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row8_col8,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col9,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row10_col10,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col11,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row12_col12,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row13_col13,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row14_col14,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row15_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row16_col16,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row17_col17,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row18_col18,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row19_col19,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col20,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row21_col21,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row22_col22,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row23_col23,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row24_col24,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row25_col25,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row26_col26,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col27,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row28_col28,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row29_col29{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col1,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col20,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col22,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row24_col22,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col9{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col3,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row2_col3,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col0,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col2{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col4,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col12,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row12_col24,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row13_col16{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col5,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row1_col20,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col6,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row19_col5{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col6,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row5_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row6_col13,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row23_col6{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col7,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col7,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col13,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col24,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row25_col29,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col25{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col8,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row1_col17{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col9,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col19,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row1_col4,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row1_col8,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col0,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col1,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col3,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col10,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col12,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col13,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col20,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row9_col23,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col5,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col6,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col7,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col24,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col25,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col26,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col27,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col28,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col29,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row14_col21,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row14_col22,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row18_col21,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col14,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col18,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row21_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row21_col16,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row21_col17,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row28_col11{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col10,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row28_col8{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col11{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col12,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row5_col22,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row15_col26,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col6,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row26_col20{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col13,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row6_col3,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row10_col0,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row10_col2,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row12_col2{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col14,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row14_col7,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col19,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col11{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row20_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row28_col12,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row29_col11{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col16,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row4_col21,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row11_col16,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row24_col18,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row27_col14{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col17,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row5_col18,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row10_col4,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row12_col15,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row15_col11,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row17_col11,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row21_col28,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row24_col3{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row0_col18,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row2_col14,#T_95c953ee_2592_11eb_aca0_c0b5d791f0c4row3_col9,#T_95c953e

# %% [markdown]
# - As can be seen from the correlation matrix, some features have much higher correlation among them **(greater than 90%)**.
# - perimeter_mean, area_mean, radius_worst, perimeter_worst and area_worst are highly correlated with radius_mean feature

# %% [markdown]
# ### Check for the outliers using boxplot

# %%
# Mean features of the dataset
data = (df.iloc[:, 2:] - df.iloc[:, 2:].mean()) / (df.iloc[:, 2:].std())      
data = pd.concat([df.Diagnosis, data.iloc[:, 0:10]], axis = 1)
data = pd.melt(data, id_vars = "Diagnosis", var_name = "features", value_name = 'value')

plt.figure(figsize = (14, 10))
sns.boxplot(x = "features", y = "value", hue = "Diagnosis", data = data)
plt.title('Target Variable distribution as a function of Mean feature columns', fontsize = 15)
plt.xticks(rotation = 90);

# %%
# SE features of the dataset
data = (df.iloc[:, 2:] - df.iloc[:, 2:].mean()) / (df.iloc[:, 2:].std())      
data = pd.concat([df.Diagnosis, data.iloc[:, 10:20]], axis = 1)
data = pd.melt(data, id_vars = "Diagnosis", var_name = "features", value_name = 'value')

plt.figure(figsize = (14, 10))
sns.boxplot(x = "features", y = "value", hue = "Diagnosis", data = data)
plt.title('Target Variable distribution as a function of SE feature columns', fontsize = 15)
plt.xticks(rotation = 90);

# %%
# Worst features of the dataset
data = (df.iloc[:, 2:] - df.iloc[:, 2:].mean()) / (df.iloc[:, 2:].std())      
data = pd.concat([df.Diagnosis, data.iloc[:, 20:30]], axis = 1)
data = pd.melt(data, id_vars = "Diagnosis", var_name = "features", value_name = 'value')

plt.figure(figsize = (14, 10))
sns.boxplot(x = "features", y = "value", hue = "Diagnosis", data = data)
plt.title('Target Variable distribution as a function of Worst feature columns', fontsize = 15)
plt.xticks(rotation = 90);

# %% [markdown]
# ### Observations from the box plots
# - As can be seen from the above box plots, there are outliers present in most of the features in the dataset.
# - **Standard Error features have most number of outliers**.
# - Entries corresponding to Malignant have higher values as compared to Benign

# %% [markdown]
# ### Find the top correlations among the variables in the dataset

# %%
def filter_redundant_pairs(df):
    """ This function will filter the redundant pairs of correlated features in the dataset
        Args:
            df: dataframe
    """
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i + 1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop


def top_correlations(df, n = 5):
    """ This function will return the top n correlated features in the dataset
        Args:
            df: dataframe
            n: number of correlated features to return 
    """
    au_corr = df.corr().abs().unstack()
    labels_to_drop = filter_redundant_pairs(df)
    au_corr = au_corr.drop(labels = labels_to_drop).sort_values(ascending = False)
    return au_corr[0:n]


print("Top Absolute Correlations")
print(top_correlations(df.iloc[:, 2:], 20))
# Out:
# Top Absolute Correlations
# radius_mean      perimeter_mean         0.997855
# radius_worst     perimeter_worst        0.993708
# radius_mean      area_mean              0.987357
# perimeter_mean   area_mean              0.986507
# radius_worst     area_worst             0.984015
# perimeter_worst  area_worst             0.977578
# radius_se        perimeter_se           0.972794
# perimeter_mean   perimeter_worst        0.970387
# radius_mean      radius_worst           0.969539
# perimeter_mean   radius_worst           0.969476
# radius_mean      perimeter_worst        0.965137
# area_mean        radius_worst           0.962746
#                  area_worst             0.959213
#                  perimeter_worst        0.959120
# radius_se        area_se                0.951830
# perimeter_mean   area_worst             0.941550
# radius_mean      area_worst             0.941082
# perimeter_se     area_se                0.937655
# concavity_mean   concave_points_mean    0.921391
# texture_mean     texture_worst          0.912045
# dtype: float64

# %% [markdown]
# ### Split the data into train, test and validation set

# %%
# separate the target variable
target = df.Diagnosis

X, x_test, Y, y_test = train_test_split(df.iloc[:, 2:], target, test_size = 0.1, stratify = target, random_state = 42)
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size = 0.15, stratify = Y, random_state = 42)

print(f'Shape of x_train: {x_train.shape}\nShape of y_train is: {y_train.shape}')
print(f'Shape of x_test: {x_test.shape}\nShape of y_train is: {y_test.shape}')
print(f'Shape of x_val: {x_val.shape}\nShape of y_train is: {y_val.shape}')
# Out:
# Shape of x_train: (435, 30)
# Shape of y_train is: (435,)
# Shape of x_test: (57, 30)
# Shape of y_train is: (57,)
# Shape of x_val: (77, 30)
# Shape of y_train is: (77,)

# %% [markdown]
# ### Base line DecisionTreeClassifier model

# %%
tree_clf = DecisionTreeClassifier(random_state = 42)
tree_clf.fit(x_train, y_train)
tree_pred_baseline = tree_clf.predict(x_val)
confusion_matrix(y_val, tree_pred_baseline)
# Out:
# array([[47,  1],
#        [ 6, 23]], dtype=int64)

# %%
print(f'Accuracy of baseline tree classifier is {accuracy_score(y_val, tree_pred_baseline)}')
print(f'F1 Score of baseline tree classifier is {f1_score(y_val, tree_pred_baseline, average = None)}')
# Out:
# Accuracy of baseline tree classifier is 0.9090909090909091
# F1 Score of baseline tree classifier is [0.93069307 0.86792453]

# %% [markdown]
# ### Base line RandomForestClassifier model

# %%
rf_clf = RandomForestClassifier(random_state = 42)
rf_clf.fit(x_train, y_train)
rf_pred_baseline = rf_clf.predict(x_val)
confusion_matrix(y_val, rf_pred_baseline)
# Out:
# array([[48,  0],
#        [ 2, 27]], dtype=int64)

# %%
print(f'Accuracy of baseline random forest classifier is {accuracy_score(y_val, rf_pred_baseline)}')
print(f'F1 Score of baseline random forest classifier is {f1_score(y_val, rf_pred_baseline, average = None)}')
# Out:
# Accuracy of baseline random forest classifier is 0.974025974025974
# F1 Score of baseline random forest classifier is [0.97959184 0.96428571]

# %% [markdown]
# ### 5 Fold Cross Validation on DecisionTreeClassifier

# %%
cv = KFold(n_splits = 5, shuffle = True, random_state = 42)

# create model
tree_model = DecisionTreeClassifier(criterion = 'entropy', random_state = 42)

# evaluate model
tree_scores = cross_val_score(tree_model, X, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)

# report performance
print('Accuracy: %.3f' % (np.mean(tree_scores)))
# Out:
# Accuracy: 0.920

# %% [markdown]
# ### 5 Fold Cross Validation on RandomForestClassifier

# %%
# create model
rf_model = RandomForestClassifier(random_state = 42)

# evaluate model
rf_scores = cross_val_score(rf_model, X, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)

# report performance
print('Accuracy: %.3f' % (np.mean(rf_scores)))
# Out:
# Accuracy: 0.959

# %% [markdown]
# ### Estimating the number of trees in RandomForestClassifier

# %%
accuracy = []   # to store the accuracy for each estimator

## iterate for the number of estimators
for estimator in range(1, 500):
    cv = KFold(n_splits = 5, shuffle = True, random_state = 42)
    rf_model = RandomForestClassifier(random_state = 42, n_estimators = estimator, n_jobs = -1)
    rf_scores = cross_val_score(rf_model, X, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)
    accuracy.append(np.mean(rf_scores))

# %% [markdown]
# ### Plot the accuracy as a function of number of trees in the RandomForestClassifier

# %%
fig, ax = plt.subplots(figsize = (12, 6))

ax.plot(list(range(1, 500)), accuracy)
ax.set_title('Accuracy vs number of trees', fontsize = 15)
ax.set_xlabel('Number of trees', fontsize = 12)
ax.set_ylabel('Accuracy of model', fontsize = 12)

# maximum accuracy line
ax.axvline(x = np.argmax(accuracy) + 1, color = 'r');

# %% [markdown]
# ### Varying max features to observe its effect on accuracy

# %%
acc_max_feat = []   # to store accuracy for different max features

## iterate over the max features
for max_feat in range(1, 31):
    cv = KFold(n_splits = 5, shuffle = True, random_state = 42)
    rf_model = RandomForestClassifier(random_state = 42, n_estimators = 43, max_features = max_feat, n_jobs = -1)
    rf_scores = cross_val_score(rf_model, X, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)
    acc_max_feat.append(np.mean(rf_scores))

# %% [markdown]
# ### Plot the accuracy as a function of max features in the RandomForestClassifier

# %%
fig, ax = plt.subplots(figsize = (12, 6))

ax.plot(list(range(1, 31)), acc_max_feat)
ax.set_title('Accuracy vs Feature size', fontsize = 15)
ax.set_xlabel('Feature Size', fontsize = 12)
ax.set_ylabel('Accuracy of model', fontsize = 12)

# maximum accuracy line
ax.axvline(x = np.argmax(acc_max_feat) + 1, color = 'r');

# %% [markdown]
# ### Let's evaluate the performance RandomForest model on test data

# %%
rf_model = RandomForestClassifier(random_state = 42, n_estimators = 43, max_features = 5, n_jobs = -1)
rf_model.fit(X, Y)
test_pred = rf_model.predict(x_test)
print(f"Accuracy of random forest model on test data: {accuracy_score(y_test, test_pred)}")
confusion_matrix(y_test, test_pred)
# Out:
# Accuracy of random forest model on test data: 0.9824561403508771
# array([[36,  0],
#        [ 1, 20]], dtype=int64)

# %% [markdown]
# ### Let's drop highly correlated features from the dataset

# %%
features_to_drop = ['perimeter_mean', 'perimeter_worst', 'perimeter_se', 'area_mean', 'area_se', 'area_worst', 'radius_worst', 
                    'radius_se', 'concave_points_mean', 'concave_points_worst', 'concavity_mean', 'concavity_worst', 
                    'texture_worst', 'compactness_mean', 'compactness_worst', 'compactness_se']

new_df = df.drop(features_to_drop, axis = 1)
new_df.head()
# Out:
#          ID Diagnosis  radius_mean  texture_mean  smoothness_mean  \
# 0    842302         M        17.99         10.38          0.11840
# 1    842517         M        20.57         17.77          0.08474
# 2  84300903         M        19.69         21.25          0.10960
# 3  84348301         M        11.42         20.38          0.14250
# 4  84358402         M        20.29         14.34          0.10030
#
#    symmetry_mean  fractal_dimension_mean  texture_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053       0.006399
# 1         0.1812                 0.05667      0.7339       0.005225
# 2         0.2069                 0.05999      0.7869       0.006150
# 3         0.2597                 0.09744      1.1560       0.009110
# 4         0.1809                 0.05883      0.7813       0.011490
#
#    concavity_se  concave_points_se  symmetry_se  fractal_dimension_se  \
# 0       0.05373            0.01587      0.03003              0.006193
# 1       0.01860            0.01340      0.01389              0.003532
# 2       0.03832            0.02058      0.02250              0.004571
# 3       0.05661            0.01867      0.05963              0.009208
# 4       0.05688            0.01885      0.01756              0.005115
#
#    smoothness_worst  symmetry_worst  fractal_dimension_worst
# 0            0.1622          0.4601                  0.11890
# 1            0.1238          0.2750                  0.08902
# 2            0.1444          0.3613                  0.08758
# 3            0.2098          0.6638                  0.17300
# 4            0.1374          0.2364                  0.07678

# %%
# check the shape of the new data frame after dropping correlated features
new_df.shape
# Out:
# (569, 16)

# %% [markdown]
# ### Check the correlation after dropping features from the dataset

# %%
random_state = np.random.RandomState(0)
new_corr = new_df.iloc[:, 2:].corr()
new_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
# #T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col0,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col1,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col2,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row4_col4,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col5,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row6_col6,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row7_col7,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row8_col8,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row9_col9,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row10_col10,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col11,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row12_col12,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col1,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row7_col9{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col2{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col8,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col9{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col4,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col6,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col9,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col10,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col2,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col7,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row4_col0,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row4_col1,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col11,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col12,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row12_col5,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row12_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col5,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col7{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col7,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col7{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col8{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col11,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row13_col1{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col12,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row4_col5{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row0_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col1,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col5{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col4{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col5,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col6{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col6{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col8{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col9,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row5_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col10{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col11,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row6_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col1{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col12,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row7_col1,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row10_col0,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row11_col10{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row1_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row9_col0{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col0{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row8_col0{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col4,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row10_col7{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col7,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row6_col3,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row10_col1{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col8,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col9{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col10{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col11{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col12,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row7_col13{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row2_col13,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row9_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col1{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col2{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col4{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col5,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row10_col11{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col6{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col7,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row4_col8{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col8,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row7_col3{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col9,#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row9_col4{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_762b5de8_2595_11eb_aff8_c0b5d791f0c4row3_col10{
#             backgr

# %% [markdown]
# ### Prepare data with dropped features

# %%
# drop the features from train, test and validation data sets
X_new = X.drop(features_to_drop, axis = 1)
x_train_new = x_train.drop(features_to_drop, axis = 1)
x_test_new = x_test.drop(features_to_drop, axis = 1)
x_val_new = x_val.drop(features_to_drop, axis = 1)

# %% [markdown]
# ### DecisionTree Classifier with dropped features

# %%
cv = KFold(n_splits = 5, shuffle = True, random_state = 42)

# create model
new_tree_model = DecisionTreeClassifier(random_state = 42)

# evaluate model
new_tree_scores = cross_val_score(new_tree_model, X_new, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)

# report performance
print('Accuracy: %.3f' % (np.mean(new_tree_scores)))
# Out:
# Accuracy: 0.918

# %% [markdown]
# ### RandomForestClassifier with dropped features

# %%
# create model
new_rf_model = RandomForestClassifier(random_state = 42)

# evaluate model
new_rf_scores = cross_val_score(new_rf_model, X_new, Y, scoring = 'accuracy', cv = cv, n_jobs = -1)

# report performance
print('Accuracy: %.3f' % (np.mean(new_rf_scores)))
# Out:
# Accuracy: 0.945

# %% [markdown]
# ### Let's evaluate the performance RandomForest model on test data

# %%
rf_model = RandomForestClassifier(random_state = 42, n_estimators = 43, max_features = 5, n_jobs = -1)
rf_model.fit(X_new, Y)
test_pred = rf_model.predict(x_test_new)
print(f"Accuracy of random forest model on test data: {accuracy_score(y_test, test_pred)}")
confusion_matrix(y_test, test_pred)
# Out:
# Accuracy of random forest model on test data: 0.9649122807017544
# array([[35,  1],
#        [ 1, 20]], dtype=int64)

# %% [markdown]
# ## Conclusion
#
# #### Accuracy
# - Random Forest Classifier performed better than Decision Tree Classifier on this data set
# - Accuracy of RandomForestClassifier on the test data without dropping any features from the dataset is 98.24 %.
# - Accuracy of RandomForestClassifier on the test data after dropping correlated features from the dataset is 96.49%
#
# - There are many features in the dataset that are highly correlated with each other.
# - Dropping them didn't cause any significant loss in accuracy.
#
# #### Outliers
# - There are outliers present in most of the features in the dataset.
# - The RandomForest model can be made more robust by removing outliers.
